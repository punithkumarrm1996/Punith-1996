# %% [markdown]
# <a href="https://colab.research.google.com/github/punithkumarrm1996/Punith-1996/blob/main/DS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Write the indexing expression to print *"Edukron"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[0:7])
print(text[-52:-45])
# Out:
# Edukron
# Edukron

# %%
#2. Write the indexing expression to print "Data" (first occurrence).
text = '''Edukron Data Science and Data Engineering Batch 2026'''
print(text[8:13])
print(text[-44:-40])
# Out:
# Data
# Data

# %%
#3. Write the indexing expression to print *"Science"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[13:20])
print(text[-39:-32])
# Out:
# Science
# Science

# %%
#4. Write the indexing expression to print *"and"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[21:25])
print(text[-31:-28])
# Out:
# and
# and

# %%
#5.Write the indexing expression to print *"Data Engineering"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[25:42])
print(text[-27:-11])
# Out:
# Data Engineering
# Data Engineering

# %%
#6. Write the indexing expression to print *"Engineering"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[30:42])
print(text[-22:-11])
# Out:
# Engineering
# Engineering

# %%
#7. Write the indexing expression to print *"Batch"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[42:48])
print(text[-10:-5])
# Out:
# Batch
# Batch

# %%
#8. Write the indexing expression to print *"2026"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[48:52])
print(text[-4:])
# Out:
# 2026
# 2026

# %%
#9. Write the indexing expression to print *"Science and Data"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[13:30])
print(text[-39:-23])
# Out:
# Science and Data
# Science and Data

# %%
#10.Write the indexing expression to print *"Data Science and Data Engineering Batch"*.
text = 'Edukron Data Science and Data Engineering Batch 2026'
print(text[8:48])
print(text[-44:-5])
# Out:
# Data Science and Data Engineering Batch
# Data Science and Data Engineering Batch
