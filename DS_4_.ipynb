# %% [markdown]
# <a href="https://colab.research.google.com/github/punithkumarrm1996/Punith-1996/blob/main/DS_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 1**

# %% [markdown]
# Write a program to calculate the square root of a number using the math module.

# %%
import math

num = 25
result = math.sqrt(num)
print(result)
# Out:
# 5.0

# %% [markdown]
# **Question 2**

# %% [markdown]
# Find the cube root of a given number using mathematical operations.

# %%
num = 28
result = num ** (1/3)
print(round(result, 2))
# Out:
# 3.04

# %% [markdown]
# **Question 3**

# %% [markdown]
# Calculate the factorial of a number using math.factorial().

# %%
import math

num = 5
result = math.factorial(num)
print(result)
# Out:
# 120

# %% [markdown]
# **Question 4**

# %% [markdown]
# Find the GCD (Greatest Common Divisor) of two numbers using math.gcd().

# %%
import math

a = 24
b = 36
result = math.gcd(a, b)
print(result)
# Out:
# 12

# %% [markdown]
# **Question 5**

# %% [markdown]
# Find the LCM of two numbers using math.lcm().

# %%
import math

a = 12
b = 18
result = math.lcm(a, b)
print(result)
# Out:
# 36

# %% [markdown]
# **Question 6**

# %% [markdown]
# Calculate the value of 5 raised to the power of 8 using math.pow().

# %%
import math

result = math.pow(5, 8)
print(result)
# Out:
# 390625.0

# %% [markdown]
# **Question 7**

# %% [markdown]
# Find the absolute value of a negative decimal number using math.fabs().

# %%
import math

num = -15.75
result = math.fabs(num)
print(result)
# Out:
# 15.75

# %% [markdown]
# **Question 8**

# %% [markdown]
# Round a floating-point number up using math.ceil().

# %%
import math

num = 7.2
result = math.ceil(num)
print(result)
# Out:
# 8

# %% [markdown]
# **Question 9**

# %% [markdown]
# Round a floating-point number down using math.floor().

# %%
import math

num = 7.8
result = math.floor(num)
print(result)
# Out:
# 7

# %% [markdown]
# **Question 10**

# %% [markdown]
# Round a floating-point number to the nearest integer using round().

# %%
num = 7.6
result = round(num)
print(result)
# Out:
# 8

# %% [markdown]
# **Question 11**

# %% [markdown]
# Find the remainder of two numbers using math.fmod().

# %%
import math

a = 17
b = 5
result = math.fmod(a, b)
print(result)
# Out:
# 2.0

# %% [markdown]
# **Question 12**

# %% [markdown]
# Find the quotient and remainder using divmod().

# %%
a = 17
b = 5
result = divmod(a, b)
print(result)
# Out:
# (3, 2)

# %% [markdown]
# **Question 13**

# %% [markdown]
# Calculate the sine, cosine, and tangent of 45 degrees.

# %%
import math

angle = 45
radians = math.radians(angle)
print(math.sin(radians))
print(math.cos(radians))
print(math.tan(radians))
# Out:
# 0.7071067811865475
# 0.7071067811865476
# 0.9999999999999999

# %% [markdown]
# **Question 14**

# %% [markdown]
# Convert an angle from degrees to radians.

# %%
import math

angle = 180
result = math.radians(angle)
print(result)
# Out:
# 3.141592653589793

# %% [markdown]
# **Question 15**

# %% [markdown]
# Convert an angle from radians to degrees.

# %%
import math

radians = math.pi
result = math.degrees(radians)
print(result)
# Out:
# 180.0

# %% [markdown]
# **Question 16**

# %% [markdown]
# Find the logarithm (base 10) of a number using math.log10().

# %%
import math

num = 100
result = math.log10(num)
print(result)
# Out:
# 2.0

# %% [markdown]
# **Question 17**

# %% [markdown]
# Find the natural logarithm of a number using math.log().

# %%
import math

num = 10
result = math.log(num)
print(result)
# Out:
# 2.302585092994046

# %% [markdown]
# **Question 18**

# %% [markdown]
# Calculate e raised to the power of x using math.exp().

# %%
import math

x = 2
result = math.exp(x)
print(result)
# Out:
# 7.38905609893065

# %% [markdown]
# **Question 19**

# %% [markdown]
# Find the value of π (pi) and Euler's number (e) from the math module.

# %%
import math

print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %% [markdown]
# **Question 20**

# %% [markdown]
# Find the distance between two points using math.dist().

# %%
import math

point1 = (2, 3)
point2 = (5, 7)
result = math.dist(point1, point2)
print(result)
# Out:
# 5.0

# %% [markdown]
# **Question 21**

# %% [markdown]
# Calculate the hypotenuse of a right triangle using math.hypot().

# %%
import math

base = 3
height = 4
result = math.hypot(base, height)
print(result)
# Out:
# 5.0

# %% [markdown]
# **Question 22**

# %% [markdown]
# Find the combination (nCr) using math.comb().

# %%
import math

n = 5
r = 2
result = math.comb(n, r)
print(result)
# Out:
# 10

# %% [markdown]
# **Question 23**

# %% [markdown]
# Find the permutation (nPr) using math.perm().

# %%
import math

n = 5
r = 2
result = math.perm(n, r)
print(result)
# Out:
# 20

# %% [markdown]
# **Question 24**

# %% [markdown]
# Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan().

# %%
import math

finite_num = 10
infinite_num = math.inf
nan_num = math.nan

print(math.isfinite(finite_num))
print(math.isinf(infinite_num))
print(infinite_num)
print(math.isnan(nan_num))
print(nan_num)
# Out:
# True
# True
# inf
# True
# nan

# %% [markdown]
# **Question 25**

# %% [markdown]
# Find the product of all numbers in a list using math.prod().

# %%
import math

numbers = [2, 3, 4, 5]
result = math.prod(numbers)
print(result)
# Out:
# 120

# %% [markdown]
# **Question 26**

# %% [markdown]
# Find the sum of square roots of all numbers in a list.

# %%
import math

numbers = [4, 9, 16]
result = sum(math.sqrt(num) for num in numbers)
print(result)
# Out:
# 9.0

# %% [markdown]
# **Question 27**

# %% [markdown]
# Find the largest integer less than or equal to the square root of a given number.

# %%
import math

num = 30
result = math.floor(math.sqrt(num))
print(result)
# Out:
# 5

# %% [markdown]
# **Question 28**

# %% [markdown]
# Calculate compound interest using math.pow().

# %%
import math

principal = 10000
rate = 5
time = 2

amount = principal * math.pow((1 + rate / 100), time)
compound_interest = amount - principal
print(compound_interest)
# Out:
# 1025.0

# %% [markdown]
# **Question 29**

# %% [markdown]
# Find the area and circumference of a circle using math.pi.

# %%
import math

radius = 7
area = math.pi * radius ** 2
circumference = 2 * math.pi * radius

print(area)
print(circumference)
# Out:
# 153.93804002589985
# 43.982297150257104

# %% [markdown]
# **Question 30**

# %% [markdown]
# Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

# %%
import math

# Example values for the calculator
num = 25
n = 5
a = 12
b = 18
angle = 45

print("Square Root:", math.sqrt(num))
print("Factorial:", math.factorial(n))
print("Logarithm:", math.log10(100))
print("Power:", math.pow(2, 3))
print("Sine:", math.sin(math.radians(angle)))
print("Cosine:", math.cos(math.radians(angle)))
print("Tangent:", math.tan(math.radians(angle)))
print("GCD:", math.gcd(a, b))
print("LCM:", math.lcm(a, b))
# Out:
# Square Root: 5.0
# Factorial: 120
# Logarithm: 2.0
# Power: 8.0
# Sine: 0.7071067811865475
# Cosine: 0.7071067811865476
# Tangent: 0.9999999999999999
# GCD: 6
# LCM: 36
